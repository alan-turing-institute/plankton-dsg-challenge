# %%
import pandas as pd 
import numpy

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style('darkgrid')
sns.color_palette("cubehelix", as_cmap=True)
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
df = pd.read_csv("/home/miruna.clinciu/plankton-dsg-challenge-main/data/testdataframe.csv")

# %%
df = df.drop(['Unnamed: 0'], axis = 1)
df = df.drop(['index'], axis = 1)

# %%
df.head()
# Out:
#    object_label  object_width  object_height  object_bx  object_by  \
# 0             1            80             72          0          0
# 1             1            64             76          0          0
# 2             1            64            102          0          0
# 3             1            80             86          0          0
# 4             1            64             94          0          0
#
#    object_circ.  object_area_exc  object_area  object_%area  object_major  \
# 0      0.804248             5760         5760           0.0     92.368826
# 1      0.802390             4864         4864           0.0     87.749644
# 2      0.762504             6528         6528           0.0    117.773794
# 3      0.803620             6880         6880           0.0     99.297533
# 4      0.776620             6016         6016           0.0    108.535708
#
#    ...  object_extent  object_local_centroid_col  object_local_centroid_row  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58752 entries, 0 to 58751
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_label                58752 non-null  int64
#  1   object_width                58752 non-null  int64
#  2   object_height               58752 non-null  int64
#  3   object_bx                   58752 non-null  int64
#  4   object_by                   58752 non-null  int64
#  5   object_circ.                58752 non-null  float64
#  6   object_area_exc             58752 non-null  int64
#  7   object_area                 58752 non-null  int64
#  8   object_%area                58752 non-null  float64
#  9   object_major                58752 non-null  float64
#  10  object_minor                58752 non-null  float64
#  11  object_y                    58752 non-null  float64
#  12  object_x                    58752 non-null  float64
# ...

# %%
df['label1'].value_counts()
# Out:
# detritus       39962
# zooplankton    18790
# Name: label1, dtype: int64

# %%
df['label2'].value_counts()
# Out:
# detritus      39962
# copepod       10346
# noncopepod     8444
# Name: label2, dtype: int64

# %%
df['label3'].value_counts()
# Out:
# detritus                                    39962
# copepod_calanoida_para-pseudocalanus-spp     1988
# copepod_unknown                              1853
# radiolaria                                   1810
# copepod_calanoida                            1665
# copepod_nauplii                              1380
# copepod_cyclopoida_corycaeus-spp             1117
# echniodermata-larvae                          799
# copepod_calanoida_centropages-spp             773
# copepod_cyclopoida_oncaea-spp                 710
# copepod_harpacticoida                         643
# copepod_cyclopoida_oithona-spp                492
# nt-phyto_ceratium-spp                         459
# copepod_calanoida_acartia-spp                 451
# nt-bubbles                                    354
# copepod_calanoida_calanus-spp                 345
# appendicularia                                316
# cirripedia_barnacle-nauplii                   308
# nt_phyto_chains                               298
# ...

# %%
plt.title('Count')
matplotlib.rcParams['figure.figsize'] = (6, 10)
sns.countplot(df['label1'], palette='viridis');
# Out:
# /opt/pyenv/versions/3.8.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.title('Count')
sns.countplot(df['label2'], palette='viridis');
# Out:
# /opt/pyenv/versions/3.8.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
matplotlib.rcParams['figure.figsize'] = (40, 60)
sns.countplot(y="label3", data=df, orient='h', palette='viridis');
